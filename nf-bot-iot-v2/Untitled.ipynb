# %%
import pandas as pd

df = pd.read_csv("NF-BoT-IoT-v2-0.03.csv")
df.head()
# Out:
#    IPV4_SRC_ADDR  L4_SRC_PORT    IPV4_DST_ADDR  L4_DST_PORT  PROTOCOL  \
# 0  192.168.100.7           80  192.168.100.149        40341         6
# 1  192.168.100.3           80  192.168.100.150        38871         6
# 2  192.168.100.6           80  192.168.100.148        34243         6
# 3  192.168.100.3           80  192.168.100.147        53060         6
# 4  192.168.100.3           80  192.168.100.149        43333         6
#
#    L7_PROTO  IN_BYTES  IN_PKTS  OUT_BYTES  OUT_PKTS  ...  TCP_WIN_MAX_IN  \
# 0       7.0        44        1        180         2  ...            5840
# 1       7.0        44        1        320         3  ...           29200
# 2       7.0        40        1        280         2  ...               0
# 3       7.0        44        1        180         2  ...           29200
# 4       7.0        44        1        180         2  ...           29200
#
#    TCP_WIN_MAX_OUT  ICMP_TYPE  ICMP_IPV4_TYPE  DNS_QUERY_ID  DNS_QUERY_TYPE  \
# ...

# %%
df["Attack"].unique()
# Out:
# array(['Benign', 'DDoS', 'DoS', 'Reconnaissance', 'Theft'], dtype=object)
